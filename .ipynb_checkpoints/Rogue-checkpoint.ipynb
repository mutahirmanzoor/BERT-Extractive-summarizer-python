# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      -------------------------------------- 519.6/519.6 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from datasets) (4.64.1)
# Requirement already satisfied: packaging in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from datasets) (6.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.5-cp39-cp39-win_amd64.whl (327 kB)
#      -------------------------------------- 327.1/327.1 kB 2.9 MB/s eta 0:00:00
# Collecting fsspec[http]<2023.9.0,>=2023.1.0
#   Downloading fsspec-2023.6.0-py3-none-any.whl (163 kB)
#      ------------------------------------ 163.8/163.8 kB 378.3 kB/s eta 0:00:00
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from datasets) (0.3.4)
# Collecting multiprocess
#   Downloading multiprocess-0.70.15-py39-none-any.whl (133 kB)
#      -------------------------------------- 133.3/133.3 kB 1.3 MB/s eta 0:00:00
# Collecting huggingface-hub<1.0.0,>=0.14.0
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      -------------------------------------- 295.0/295.0 kB 3.1 MB/s eta 0:00:00
# Collecting pyarrow>=8.0.0
#   Downloading pyarrow-13.0.0-cp39-cp39-win_amd64.whl (24.4 MB)
#      ---------------------------------------- 24.4/24.4 MB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from datasets) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from datasets) (1.21.5)
# Requirement already satisfied: requests>=2.19.0 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from datasets) (2.28.1)
# Collecting xxhash
#   Downloading xxhash-3.3.0-cp39-cp39-win_amd64.whl (29 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from aiohttp->datasets) (2.0.4)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp39-cp39-win_amd64.whl (61 kB)
#      ---------------------------------------- 61.7/61.7 kB 1.7 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-win_amd64.whl (28 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from aiohttp->datasets) (21.4.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.0-cp39-cp39-win_amd64.whl (44 kB)
#      ---------------------------------------- 44.7/44.7 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.3.0)
# Requirement already satisfied: filelock in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: colorama in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Collecting dill<0.3.8,>=0.3.0
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      -------------------------------------- 115.3/115.3 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, pyarrow, multidict, fsspec, frozenlist, dill, async-timeout, yarl, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.7.1
#     Uninstalling fsspec-2022.7.1:
#       Successfully uninstalled fsspec-2022.7.1
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.4
#     Uninstalling dill-0.3.4:
#       Successfully uninstalled dill-0.3.4
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.13.2
#     Uninstalling huggingface-hub-0.13.2:
#       Successfully uninstalled huggingface-hub-0.13.2
# Successfully installed aiohttp-3.8.5 aiosignal-1.3.1 async-timeout-4.0.3 datasets-2.14.5 dill-0.3.7 frozenlist-1.4.0 fsspec-2023.6.0 huggingface-hub-0.17.3 multidict-6.0.4 multiprocess-0.70.15 pyarrow-13.0.0 xxhash-3.3.0 yarl-1.9.2

# %%
import torch 
from datasets import load_dataset

full_dataset=load_dataset("cnn_dailymail")
# Out:
# Downloading builder script:   0%|          | 0.00/8.33k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/9.88k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/15.1k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5108\3794364826.py in <module>
#       2 from datasets import load_dataset
#       3
# ----> 4 full_dataset=load_dataset("cnn_dailymail")
#
# ~\anaconda3\lib\site-packages\datasets\load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2127
#    2128     # Create a dataset builder
# -> 2129     builder_instance = load_dataset_builder(
#    2130         path=path,
#    2131         name=name,
#
# ~\anaconda3\lib\site-packages\datasets\load.py in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, use_auth_token, storage_options, **config_kwargs)
#    1850     builder_cls = get_dataset_builder_class(dataset_module, dataset_name=dataset_name)
#    1851     # Instantiate the dataset builder
# -> 1852     builder_instance: DatasetBuilder = builder_cls(
#    1853         cache_dir=cache_dir,
#    1854         dataset_name=dataset_name,
#
# ~\anaconda3\lib\site-packages\datasets\builder.py in __init__(self, cache_dir, dataset_name, config_name, hash, base_path, info, features, token, use_auth_token, repo_id, data_files, data_dir, storage_options, writer_batch_size, name, **config_kwargs)
#     371         if data_dir is not None:
#     372             config_kwargs["data_dir"] = data_dir
# --> 373         self.config, self.config_id = self._create_builder_config(
#     374             config_name=config_name,
#     375             custom_features=features,
#
# ~\anaconda3\lib\site-packages\datasets\builder.py in _create_builder_config(self, config_name, custom_features, **config_kwargs)
#     523                 if len(self.BUILDER_CONFIGS) > 1:
#     524                     example_of_usage = f"load_dataset('{self.dataset_name}', '{self.BUILDER_CONFIGS[0].name}')"
# --> 525                     raise ValueError(
#     526                         "Config name is missing."
#     527                         f"\nPlease pick one among the available configs: {list(self.builder_configs.keys())}"
#
# ValueError: Config name is missing.
# Please pick one among the available configs: ['3.0.0', '1.0.0', '2.0.0']
# Example of usage:
# 	`load_dataset('cnn_dailymail', '3.0.0')`

# %%
import torch 
from datasets import load_dataset

full_dataset=load_dataset("cnn_dailymail",version="3.0.0")
# Out:
# Downloading data files:   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/159M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/376M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/12.3M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/661k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/572k [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]

# %%
sample_size=50
sample=(full_dataset["train"]
       .filter(lambda r: "CNN" in r["article"][:25])
       .shuffle(seed=42)
        .select(range(sample_size))
       
       )
sample
# Out:
# Dataset({
#     features: ['article', 'highlights', 'id'],
#     num_rows: 50
# })

# %%
display(sample.to_pandas())
# Out:
#                                               article  \
# 0   (CNN) -- A magnitude 6.7 earthquake rattled Pa...
# 1   (CNN) -- Pakistan took big steps towards level...
# 2   (CNN) -- Federal prosecutors are pushing to fo...
# 3   Centennial, Colorado (CNN) -- McKayla Hicks sa...
# 4   (CNN) -- Double-amputee sprinter Oscar Pistori...
# 5   (CNN) -- A grand jury has indicted Texas Gov. ...
# 6   (CNN)An Argentine prosecutor said Friday there...
# 7   Warsaw, Poland (CNN) -- European football's go...
# 8   (CNN) -- Two issues -- security and immigratio...
# 9   (CNN)  -- More than 100 police officers and ot...
# 10  (CNN) -- The snowfall might be subsiding in th...
# 11  (CNN) -- Many areas are still dealing with flo...
# 12  (CNN) -- The 20th Annual Screen Actors Guild A...
# 13  New York (CNN) -- The terrorist attacks of Sep...
# 14  NAIROBI, Kenya (CNN) -- Gangs of young men arm...
# 15  (CNN) -- When Superstorm Sandy hit the eastern...
# 16  (CNN) -- On the same day voters head to the po...
# 17  Washington (CNN) -- After weeks of U.S. and NA...
# 18  Washington (CNN) -- Grimacing with emotion, en...
# 19  (CNN) -- Police in Colombia have arrested four...
# 20  (CNN) -- Yaya Toure believes that Manchester C...
# 21  Atlanta, Georgia (CNN) -- The cholera epidemic...
# 22  HONG KONG, China (CNN) -- "The Earth is just t...
# 23  (CNN) -- Mexican migration to the United State...
# 24  (CNN) -- It was the first house she looked at ...
# 25  DECATUR, Georgia (CNN) -- Police quietly wait ...
# 26  Washington (CNN) -- The Senate on Thursday pas...
# 27  Beirut, Lebanon (CNN) -- A top Lebanese intell...
# 28  (CNN) -- A number of Chipotle employees across...
# 29  (CNN) -- Dubai is home to the tallest building...
# 30  New York (CNN) -- Evelyn Lauder, a member of t...
# 31  (CNN) -- iTunes? Old news. Radio? Ancient hist...
# 32  (CNN)  -- Forget World Cups. For many rugby un...
# 33  (CNN) -- Pakistani Taliban leader Qari Hussain...
# 34  (CNN) -- The USS George Washington is expected...
# 35  (CNN)  -- Last year, the bus in which a young ...
# 36  (CNN) -- We've finally emerged from the season...
# 37  (CNN) -- Ayat Al-Qassab carefully slipped the ...
# 38  CHICAGO, Illinois (CNN)  -- A clerk's quick fl...
# 39  (CNN) -- Three experienced hikers were rescued...
# 40  Kabul, Afghanistan (CNN) -- The Afghan Taliban...
# 41  Washington (CNN)He ousted Egypt's first democr...
# 42  (CNN) -- The Florida judge presiding over the ...
# 43  Hong Kong (CNN) -- At least 2,800 dead pigs ha...
# 44  (CNN) -- A JetBlue flight from Boston, Massach...
# 45  Washington (CNN)  -- President Obama told his ...
# 46  (CNN) -- A Nevada city councilwoman who faced ...
# 47  Islamabad, Pakistan (CNN) -- The U.S. governme...
# 48  (CNN) -- Officers involved in a 2012 shooting ...
# 49  (CNN) -- Rapper T.I., who was sentenced to a 3...
#
#                                            highlights  \
# 0   Papua New Guinea is on the so-called Ring of F...
# 1   Australia collapse to 88 all out on opening da...
# 2   Jared Loughner is refusing the government's re...
# 3   Shooting victim McKayla Hicks went to hearing ...
# 4   Oscar Pistorius to become first double-amputee...
# 5   NEW: Perry lawyer calls indictments "political...
# 6   Prosecutor to judge: Enough evidence for inves...
# 7   NEW: UEFA president Michel Platini urges fans ...
# 8   A new high-level group to discuss economic coo...
# 9   Four inmates escape from jail in St. Tammany P...
# 10  NEW: Authorities worry some buildings could co...
# 11  Louisiana: Levee intentionall breached to drai...
# 12  SAG Award nominations leave out Robert Redford...
# 13  9/11 led U.S. to strike back at al Qaeda and t...
# 14  NEW: Red Cross: 120 people have been reported ...
# 15  United Way's Hurricane Sandy Recovery Fund hel...
# 16  Greg Orman tells CNN he's confident about his ...
# 17  NEW: The opposition lacks a detailed plan, a s...
# 18  NEW: Rooney says he "suffered silently" for ye...
# 19  Colombian police say they've detained four sus...
# 20  Manchester City midfielder Yaya Toure says the...
# 21  U.S. report says the cholera outbreak's course...
# 22  Explorer Mike Horn aims to encourage new gener...
# 23  NEW: "It's not the United States it was 30 yea...
# 24  Friends, family: Nothing about Amanda Knox's p...
# 25  Georgia county operates aggressive program to ...
# 26  Defense authorization bill passes Senate in 93...
# 27  NEW: An FBI team is en route to Lebanon .\nThr...
# 28  Chipotle employees in Minnesota were fired aft...
# 29  The Dubai Mall recently acquired a giant squid...
# 30  Evelyn Lauder dies from complications of ovari...
# 31  YouTube is now most popular way teens listen t...
# 32  British and Irish Lions are selected from Engl...
# 33  Qari Hussain Mehsud's notoriety includes alleg...
# 34  U.S. Navy says two amphibious ships are to arr...
# 35  Lezhnev, Prendergast: Congo "conflict minerals...
# 36  Steven Johnson: By almost any measure, life in...
# 37  Many Syrians are determined to live their live...
# 38  Store clerk switches on PA system after being ...
# 39  Two hikers still missing are from a separate g...
# 40  NEW: Nuland: "We are prepared to support a pro...
# 41  Republicans praise tough Egyptian line on radi...
# 42  Judge allows Zimmerman defense to introduce Tr...
# 43  NEW: Pig carcasses test positive for porcine c...
# 44  Witnesses said fight broke out after someone w...
# 45  Obama discusses options with war council Wedne...
# 46  Councilwoman Donna Fairchild faced possible sa...
# 47  Kashmiri was seen at the location of the strik...
# 48  The nine officers allege racial discrimination...
# 49  T.I. performed Sunday, less than two days befo...
#
#                                           id
# 0   8093dba7bc2260c26f18939826909ef27549c758
# 1   67d626156f971d0bf55e5f2a48e1ed965eb622a6
# 2   0d02fb8f0d406db956b128a5c1cc7bf3f13860a6
# 3   39aee887c6d34bd311c826142b14037e6f2639ee
# 4   cc83ecdf08f0b598c3b97b3e2819c7e0ae7ca4f2
# 5   51fb6465303595cb201b427ca04b594b182a9722
# 6   f4d3394791035a0571f1841d5d21661fdb39d74f
# 7   76ba8e9110a66a1b1293abe34ef4fab254371af8
# 8   fbca9bf96c440bbfab59de6bd5f6d06ed609ed99
# 9   a91b42eb3bfaa9dd1d6fe5e07d595f0acdbf29bc
# 10  74ffaa6de55fb976e72a74119ae21f0c853c4646
# 11  b989bdc1a3f6a243899b6017e3fdb8367fa98f88
# 12  5f3fbeb515439e71856261eb991a75e2b1719dca
# 13  ef735e9e8eb67794ee7c21bcab5015aa3b1aa7c9
# 14  4192ba32e5bf2064d0d1b06e8d5b80eb434c72c5
# 15  49da97cb5c1200877039fb816d29a5fb2adcc323
# 16  2acfb9a655af56399b46944e5d4f4ee79e2115e8
# 17  779305dd2106d2f3d8fd8a34dd944705d8551642
# 18  94dc27b8d2a7993c86f1f9abdfa7698f9d78b6b8
# 19  489d5290be9f50f4162d32edb81dd29a1900951c
# 20  4bbeb5b91f3b8dd77d7f3e276d82448ba08ea4d9
# 21  24ec273764e0ddb37d91165328cb061216e26815
# 22  39a40dcac9c2666a0c05ecb6a8954e89ecb913c0
# 23  1f545b0295ac33a1cba6d00157be4be313a0b820
# 24  fb017e38cc560e418786c9f4e443f5668bf9eb75
# 25  e82cc00daf7771c0b92386c369c4cb2e3018d304
# 26  3632c250801a2bd3e591948569596d57290fc67f
# 27  75ce1091c2c8472b2b164cb37ebb1beadfc5a39c
# 28  5ab37515ab272eefc07ce1ec7b9d0c137ae7f9f5
# 29  6fa0c798dc4d3128b9029aa4e9630f8deba3c1b3
# 30  7782497fde9b79b85bb2519b22e0ebab2e0dc4cd
# 31  93a112cb8e74a6fe3f939bf5331f54181a56ae43
# 32  d1720ec6c9905d6fbe023a2e940d45bb86a21546
# 33  3e7443939ed3c13b45db83f014b1cd0f66e26ff6
# 34  61015dd250029b6395911fd0e9440f267cbe01c7
# 35  9f1dfa7d3b8d5f1d656b3945028597e2721a7caa
# 36  0e20179f3ea218ccc192a3234e6cad90100cf531
# 37  a15b4853a07b1df48f2905fd40b06ddf6e0f4171
# 38  e26d9215e36caeee46bb871e6c47b01aae78e2a5
# 39  2a8b4d2c48cfc1569ca5e04138fc91efe4bc7311
# 40  c0b60f7442a6683faa956aec7df151b221d78b0f
# 41  23e4c98973e46be5bf8d7edc0e51413db5c3c5b2
# 42  e1b99b69c537a4210399431ad768602dbc5ef7a4
# 43  0b04f21f5bf9fd5a47890d8b42e64b9c83915d4d
# 44  acda8749fba5e9553e9f47cef89ef85eae5ad4e3
# 45  40f0561cbe3bd7561642b58441110679524b9908
# 46  56481ba39eae0159491798309710bda2fd31bdf6
# 47  ee69e8bc757c55125e1fbd36ecadb1ef8e7d2c99
# 48  17f395775730250954e25b3b3a8d32afa934c254
# 49  81802bbc59edfa8df8847f7defac46252bedd4b2

# %%
example_article=sample["article"][0]
example_summary=sample["highlights"][0]
print(f"Article:\n{example_article}\n")
print(f"Summary:\n{example_summary}\n")
# Out:
# Article:
# (CNN) -- A magnitude 6.7 earthquake rattled Papua New Guinea early Friday afternoon, according to the U.S. Geological Survey. The quake was centered about 200 miles north-northeast of Port Moresby and had a depth of 28 miles. No tsunami warning was issued, according to the Tsunami Warning Center. Papua New Guinea is on the so-called Ring of Fire, an arc of fault lines circling the Pacific Basin that is prone to frequent earthquakes and volcanic eruptions.
#
# Summary:
# Papua New Guinea is on the so-called Ring of Fire .
# It's on an arc of fault lines that is prone to frequent earthquakes .
# No tsunami warning was issued .

# %%
! pip install simplet5
# Out:
# Collecting simplet5
#   Downloading simplet5-0.1.4.tar.gz (7.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from simplet5) (1.21.5)
# Requirement already satisfied: pandas in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from simplet5) (1.4.4)
# Requirement already satisfied: sentencepiece in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from simplet5) (0.1.97)
# Requirement already satisfied: torch!=1.8.0,>=1.7.0 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from simplet5) (2.0.0)
# Collecting transformers==4.16.2
#   Downloading transformers-4.16.2-py3-none-any.whl (3.5 MB)
#      ---------------------------------------- 3.5/3.5 MB 1.4 MB/s eta 0:00:00
# Collecting pytorch-lightning==1.5.10
#   Downloading pytorch_lightning-1.5.10-py3-none-any.whl (527 kB)
#      ------------------------------------ 527.7/527.7 kB 494.2 kB/s eta 0:00:00
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: future>=0.17.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from pytorch-lightning==1.5.10->simplet5) (0.18.2)
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      -------------------------------------- 952.4/952.4 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from pytorch-lightning==1.5.10->simplet5) (4.3.0)
# Collecting tensorboard>=2.2.0
#   Downloading tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
#      ---------------------------------------- 5.5/5.5 MB 742.4 kB/s eta 0:00:00
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-1.2.0-py3-none-any.whl (805 kB)
#      ------------------------------------ 805.2/805.2 kB 612.9 kB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from pytorch-lightning==1.5.10->simplet5) (4.64.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from pytorch-lightning==1.5.10->simplet5) (21.3)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from pytorch-lightning==1.5.10->simplet5) (2023.6.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from pytorch-lightning==1.5.10->simplet5) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from transformers==4.16.2->simplet5) (2022.7.9)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from transformers==4.16.2->simplet5) (0.17.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      -------------------------------------- 880.6/880.6 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from transformers==4.16.2->simplet5) (0.13.2)
# Requirement already satisfied: filelock in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from transformers==4.16.2->simplet5) (3.6.0)
# Requirement already satisfied: requests in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from transformers==4.16.2->simplet5) (2.28.1)
# Requirement already satisfied: jinja2 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from torch!=1.8.0,>=1.7.0->simplet5) (2.11.3)
# Requirement already satisfied: sympy in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from torch!=1.8.0,>=1.7.0->simplet5) (1.10.1)
# Requirement already satisfied: networkx in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from torch!=1.8.0,>=1.7.0->simplet5) (2.8.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from pandas->simplet5) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from pandas->simplet5) (2022.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->simplet5) (3.8.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from packaging>=17.0->pytorch-lightning==1.5.10->simplet5) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->simplet5) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (2.0.3)
# Collecting absl-py>=0.4
#   Downloading absl_py-2.0.0-py3-none-any.whl (130 kB)
#      ------------------------------------ 130.2/130.2 kB 959.6 kB/s eta 0:00:00
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.23.2-py2.py3-none-any.whl (181 kB)
#      ------------------------------------ 182.0/182.0 kB 367.0 kB/s eta 0:00:00
# Collecting protobuf>=3.19.6
#   Downloading protobuf-4.24.3-cp39-cp39-win_amd64.whl (430 kB)
#      ------------------------------------ 430.5/430.5 kB 655.6 kB/s eta 0:00:00
# Requirement already satisfied: markdown>=2.6.8 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (3.3.4)
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.59.0-cp39-cp39-win_amd64.whl (3.7 MB)
#      ---------------------------------------- 3.7/3.7 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from requests->transformers==4.16.2->simplet5) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from requests->transformers==4.16.2->simplet5) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from requests->transformers==4.16.2->simplet5) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from requests->transformers==4.16.2->simplet5) (2022.9.14)
# Collecting lightning-utilities>=0.8.0
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: colorama in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from tqdm>=4.41.0->pytorch-lightning==1.5.10->simplet5) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from jinja2->torch!=1.8.0,>=1.7.0->simplet5) (2.0.1)
# Requirement already satisfied: click in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from sacremoses->transformers==4.16.2->simplet5) (8.0.4)
# Requirement already satisfied: joblib in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from sacremoses->transformers==4.16.2->simplet5) (1.1.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from sympy->torch!=1.8.0,>=1.7.0->simplet5) (1.2.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->simplet5) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->simplet5) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->simplet5) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->simplet5) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->simplet5) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.5.10->simplet5) (4.0.3)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (0.2.8)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\mutahir manzoor\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.5.10->simplet5) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Building wheels for collected packages: simplet5, sacremoses
#   Building wheel for simplet5 (setup.py): started
#   Building wheel for simplet5 (setup.py): finished with status 'done'
#   Created wheel for simplet5: filename=simplet5-0.1.4-py3-none-any.whl size=6858 sha256=690a5ea4a8fdd5d0b38158709520d7e7a4085405ceb0ff2392d4dea55220faf0
#   Stored in directory: c:\users\mutahir manzoor\appdata\local\pip\cache\wheels\b5\20\c4\6b5839d63e5f3c515661948b4ce3b6da51120c65171bb14077
#   Building wheel for sacremoses (setup.py): started
#   Building wheel for sacremoses (setup.py): finished with status 'done'
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=863115a6adbddf05df6f65b59433413dcf9e4cd6d025913801d6cfeb01d4a7d2
#   Stored in directory: c:\users\mutahir manzoor\appdata\local\pip\cache\wheels\12\1c\3d\46cf06718d63a32ff798a89594b61e7f345ab6b36d909ce033
# Successfully built simplet5 sacremoses
# Installing collected packages: tensorboard-data-server, setuptools, rsa, pyDeprecate, protobuf, oauthlib, grpcio, cachetools, absl-py, sacremoses, requests-oauthlib, lightning-utilities, google-auth, transformers, torchmetrics, google-auth-oauthlib, tensorboard, pytorch-lightning, simplet5
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 63.4.1
#     Uninstalling setuptools-63.4.1:
#       Successfully uninstalled setuptools-63.4.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.27.1
#     Uninstalling transformers-4.27.1:
#       Successfully uninstalled transformers-4.27.1
# Successfully installed absl-py-2.0.0 cachetools-5.3.1 google-auth-2.23.2 google-auth-oauthlib-1.0.0 grpcio-1.59.0 lightning-utilities-0.9.0 oauthlib-3.2.2 protobuf-4.24.3 pyDeprecate-0.3.1 pytorch-lightning-1.5.10 requests-oauthlib-1.3.1 rsa-4.9 sacremoses-0.0.53 setuptools-59.5.0 simplet5-0.1.4 tensorboard-2.14.1 tensorboard-data-server-0.7.1 torchmetrics-1.2.0 transformers-4.16.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.2.2 requires pyqt5<5.13, which is not installed.
# spyder 5.2.2 requires pyqtwebengine<5.13, which is not installed.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.

# %%
from simplet5 import SimpleT5
model = SimpleT5()
# Out:
# Global seed set to 42

# %%
import pandas as pd
import torch
import gc
from transformers import AutoTokenizer, T5ForConditionalGeneration

# %%
def batch_generator(data: list, batch_size: int):
    """
    Creates batches of size `batch_size` from a list.
    """
    s = 0
    e = s + batch_size
    while s < len(data):
        yield data[s:e]
        s = e
        e = min(s + batch_size, len(data))


def summarize_with_t5(
    model_checkpoint: str, articles: list, batch_size: int = 8
) -> list:
    """
    Compute summaries using a T5 model.
    This is similar to a `pipeline` for a T5 model but does tokenization manually.

    :param model_checkpoint: Name for a model checkpoint in Hugging Face, such as "t5-small" or "t5-base"
    :param articles: List of strings, where each string represents one article.
    :return: List of strings, where each string represents one article's generated summary
    """
    if torch.cuda.is_available():
        device = "cuda:0"
    else:
        device = "cpu"

    model = T5ForConditionalGeneration.from_pretrained(
        model_checkpoint, cache_dir="../working/cache"
    ).to(device)
    tokenizer = AutoTokenizer.from_pretrained(
        model_checkpoint, model_max_length=1024, cache_dir="../working/cache"
    )

    def perform_inference(batch: list) -> list:
        inputs = tokenizer(
            batch, max_length=1024, return_tensors="pt", padding=True, truncation=True
        )

        summary_ids = model.generate(
            inputs.input_ids.to(device),
            attention_mask=inputs.attention_mask.to(device),
            num_beams=2,
            min_length=0,
            max_length=40,
        )
        return tokenizer.batch_decode(summary_ids, skip_special_tokens=True)

    res = []

    summary_articles = list(map(lambda article: "summarize: " + article, articles))
    for batch in batch_generator(summary_articles, batch_size=batch_size):
        res += perform_inference(batch)

        torch.cuda.empty_cache()
        gc.collect()

    # clean up
    del tokenizer
    del model
    torch.cuda.empty_cache()
    gc.collect()
    return res

# %%
t5_small_summaries = summarize_with_t5("t5-small", sample["article"])
